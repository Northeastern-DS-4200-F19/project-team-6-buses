# %%
import pandas as pd

# %%
shapes = pd.read_csv("data/MBTA_GTFS_csv/shapes.csv")

# %%
trips = pd.read_csv("data/MBTA_GTFS_csv/trips.csv")

# %%
routes = pd.read_csv("data/MBTA_GTFS_csv/routes.csv")

# %%
stops = pd.read_csv("data/MBTA_GTfS_csv/stops.csv")

# %%
stop_times = pd.read_csv("data/MBTA_GTFS/stop_times.txt", iterator = True, chunksize=1000)
stop_times

# %%
stopJoin_stopTimes = pd.merge(stops,stop_times, on="stop_id", how="inner")

# %%
stopJoin_stopTimes
# Out:
#        Unnamed: 0          stop_id  stop_code                  stop_name  \
# 0             116           109802   109802.0  Saratoga St @ Teragram St
# 1             116           109802   109802.0  Saratoga St @ Teragram St
# 2             116           109802   109802.0  Saratoga St @ Teragram St
# 3             116           109802   109802.0  Saratoga St @ Teragram St
# 4             116           109802   109802.0  Saratoga St @ Teragram St
# 5             116           109802   109802.0  Saratoga St @ Teragram St
# 6             116           109802   109802.0  Saratoga St @ Teragram St
# 7             116           109802   109802.0  Saratoga St @ Teragram St
# 8             116           109802   109802.0  Saratoga St @ Teragram St
# 9             116           109802   109802.0  Saratoga St @ Teragram St
# 10            116           109802   109802.0  Saratoga St @ Teragram St
# 11            116           109802   109802.0  Saratoga St @ Teragram St
# ...
