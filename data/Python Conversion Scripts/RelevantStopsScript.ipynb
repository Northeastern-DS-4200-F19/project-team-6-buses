# %%
import pandas as pd

# %%
stop_times = pd.read_csv('MBTA_GTFS/stop_times.txt', skiprows = 500000, names = ['trip_id', 'arrival_time', 'departure_time', 'stop_id', 'stop_sequence', 'stop_headsign', 'pickup_type', 'drop_off_type', 'timepoint', 'checkpoint_id'])

#stop_times = pd.concat(chunk for chunk in stop_times_iter)
#chunksize = 10 ** 8
#for chunk in pd.read_csv('MBTA_GTFS/stop_times.txt', chunksize=chunksize):
    #process(chunk)

# %%
stop_times.head()
# Out:
#                                      trip_id arrival_time departure_time  \
# 0  41841952-BabcockBCNewtonHighlandsKenmoreW     19:57:00       19:57:00
# 1  41841952-BabcockBCNewtonHighlandsKenmoreW     19:58:00       19:58:00
# 2  41841952-BabcockBCNewtonHighlandsKenmoreW     20:00:00       20:00:00
# 3  41841952-BabcockBCNewtonHighlandsKenmoreW     20:01:00       20:01:00
# 4  41841952-BabcockBCNewtonHighlandsKenmoreW     20:03:00       20:03:00
#
#   stop_id  stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 0   70249            630            NaN            0              0
# 1   70251            640            NaN            0              0
# 2   70253            650            NaN            0              0
# 3   70255            660            NaN            0              0
# 4   70257            670            NaN            0              0
#
#    timepoint checkpoint_id
# 0        0.0           NaN
# 1        0.0           NaN
# 2        0.0           NaN
# ...

# %%
stop_times[stop_times["trip_id"] == "41918674"]
# Out:
# Empty DataFrame
# Columns: [trip_id, arrival_time, departure_time, stop_id, stop_sequence, stop_headsign, pickup_type, drop_off_type, timepoint, checkpoint_id]
# Index: []

# %%
stops = pd.read_csv('MBTA_GTFS_csv/stops.csv')

# %%
stops.head()
# Out:
#    Unnamed: 0 stop_id  stop_code                      stop_name stop_desc  \
# 0           0       1        1.0   Washington St opp Ruggles St       NaN
# 1           1      10       10.0  Theo Glynn Way @ Newmarket Sq       NaN
# 2           2   10000    10000.0       Tremont St opp Temple Pl       NaN
# 3           3   10003    10003.0       Albany St opp Randall St       NaN
# 4           4   10005    10005.0     Albany St opp E Concord St       NaN
#
#   platform_code platform_name   stop_lat   stop_lon zone_id stop_address  \
# 0           NaN           NaN  42.330957 -71.082754     NaN          NaN
# 1           NaN           NaN  42.330555 -71.068787     NaN          NaN
# 2           NaN           NaN  42.355692 -71.062911     NaN          NaN
# 3           NaN           NaN  42.331591 -71.076237     NaN          NaN
# 4           NaN           NaN  42.335017 -71.071280     NaN          NaN
#
#                            stop_url level_id  location_type parent_station  \
# ...

# %%
trips = pd.read_csv('MBTA_GTFS_csv/trips.csv')

# %%
trips.head()
# Out:
#    Unnamed: 0 route_id                                       service_id  \
# 0           0        1  ColumbusDay-VeteransDay-DayafterThanksgivingDay
# 1           1        1  ColumbusDay-VeteransDay-DayafterThanksgivingDay
# 2           2        1  ColumbusDay-VeteransDay-DayafterThanksgivingDay
# 3           3        1  ColumbusDay-VeteransDay-DayafterThanksgivingDay
# 4           4        1  ColumbusDay-VeteransDay-DayafterThanksgivingDay
#
#     trip_id trip_headsign trip_short_name  direction_id block_id shape_id  \
# 0  41918674       Harvard             NaN             0   C01-10   010070
# 1  41918676       Harvard             NaN             0   C01-10   010070
# 2  41918678       Harvard             NaN             0   C01-14   010070
# 3  41918679       Harvard             NaN             0   C01-14   010070
# 4  41918680       Harvard             NaN             0   C01-10   010070
#
#    wheelchair_accessible  trip_route_type route_pattern_id  bikes_allowed
# ...

# %%
stop_stop_times = pd.merge(stops, stop_times, on="stop_id", how="inner")

# %%
stop_stop_times.head()
# Out:
#    Unnamed: 0 stop_id  stop_code                  stop_name stop_desc  \
# 0         116  109802   109802.0  Saratoga St @ Teragram St       NaN
# 1         116  109802   109802.0  Saratoga St @ Teragram St       NaN
# 2         116  109802   109802.0  Saratoga St @ Teragram St       NaN
# 3         116  109802   109802.0  Saratoga St @ Teragram St       NaN
# 4         116  109802   109802.0  Saratoga St @ Teragram St       NaN
#
#   platform_code platform_name   stop_lat   stop_lon zone_id  ... vehicle_type  \
# 0           NaN           NaN  42.383937 -70.999451     NaN  ...          3.0
# 1           NaN           NaN  42.383937 -70.999451     NaN  ...          3.0
# 2           NaN           NaN  42.383937 -70.999451     NaN  ...          3.0
# 3           NaN           NaN  42.383937 -70.999451     NaN  ...          3.0
# 4           NaN           NaN  42.383937 -70.999451     NaN  ...          3.0
#
#     trip_id arrival_time  departure_time stop_sequence  stop_headsign  \
# ...

# %%
stop_stop_times1 = stop_stop_times[["stop_id", "stop_name", "stop_lat", "stop_lon", "trip_id"]]

# %%
stop_stop_times1.head()
# Out:
#   stop_id                  stop_name   stop_lat   stop_lon   trip_id
# 0  109802  Saratoga St @ Teragram St  42.383937 -70.999451  42269888
# 1  109802  Saratoga St @ Teragram St  42.383937 -70.999451  42269889
# 2  109802  Saratoga St @ Teragram St  42.383937 -70.999451  42269890
# 3  109802  Saratoga St @ Teragram St  42.383937 -70.999451  42269891
# 4  109802  Saratoga St @ Teragram St  42.383937 -70.999451  42269892

# %%
route_stops = pd.merge(trips, stop_stop_times1, on="trip_id", how="inner")
route_stops1 = route_stops[["trip_id", "stop_id", "route_id", "stop_name", "stop_lat", "stop_lon"]]
route_stops1.head()
route_stops1.to_csv("route_stops1")

# %%
route_stops3 = route_stops1[route_stops1["route_id"] == "1"]
route_stops3
# Out:
# Empty DataFrame
# Columns: [trip_id, stop_id, route_id, stop_name, stop_lat, stop_lon]
# Index: []

# %%
route_stops2 = route_stops1[(route_stops1["route_id"] == "1") | (route_stops1["route_id"] == "43") | (route_stops1["route_id"] == "741")]

# %%
route_stops2.head()
# Out:
# Empty DataFrame
# Columns: [trip_id, stop_id, route_id, stop_name, stop_lat, stop_lon]
# Index: []
